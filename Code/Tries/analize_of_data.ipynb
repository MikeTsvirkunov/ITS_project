# %%
from json import load
from operator import itemgetter

# %%
import codecs

with codecs.open('..\\..\\Data\\Datasets\\data.json', 'r', "utf_8") as f:
    x = load(f)

# %%
# x.values()


def deep_search(js, f):
  for i in js:
    if not (type(js[i]) is dict):
      f(i, js[i])
    else:
      deep_search(js[i], f)


# # def ds(js, f):
# #   print(js)
# #   return map(lambda a: ds(js[a], f) if a is iter or a is dict else f(a), x)
# d = list()
# deep_search(x, lambda i, j: d.append(j))
# sum(d, [])
# # print(*ds(x, lambda j: d.append(j)))
# # d
# Out:
# operator.itemgetter({'История': {'знать': ['основные положения теории и методологии истории; место истории в системе гуманитарного знания; закономерности и этапы исторического процесса', 'основные события и процессы истории России; основные источники исторического знания; историческую обусловленность современных общественно-политических процессов; взаимосвязь и особенности истории России и мира'], 'уметь': ['формулировать и обосновывать свою позицию по вопросам', 'касающимся отношения к историческому прошлому; проводить комплексный поиск исторической информации в источниках различного типа; устанавливать причинно-следственные связи между явлениями', 'пространственные и временные рамки исторических процессов и явлений'], 'владеть': ['основными методами работы с историческими источниками; приемами участия в дискуссиях по историческим проблемам; навыками представления результатов изучения исторического материала']}, 'Иностранный язык': {'знать': ['основы делового иностранного языка', 'д
# ...
